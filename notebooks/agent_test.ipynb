# %% [markdown]
# # Teste do Agente Data Mesh com Databricks
#
# Este notebook demonstra a execução da arquitetura de agentes sequenciais (Logística -> Finanças -> COO).
#
# Certifique-se de que os arquivos CSV do Olist estejam na pasta `data/`.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
from IPython.display import display, Markdown

# Adiciona o diretório atual ao path para garantir que o pacote 'app' seja encontrado
sys.path.append(os.getcwd())

# %%
from app.orchestrator import Orchestrator

# Inicializa o Orquestrador
# Isso vai criar os bancos de dados Spark e carregar os CSVs
orch = Orchestrator()

# %%
# Executa o Pipeline de Agentes
plan = orch.run_pipeline()

# %%
display(Markdown(plan))
